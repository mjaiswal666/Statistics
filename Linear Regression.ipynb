# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random

# %%
'''Age=[]
Weight=[]

for i in range(1000):
    Age.append(random.randint(22,70))
    Weight.append(random.randint(40,90))'''

# %%
#plt.scatter(Age,Weight)

# %%
age=[]
weight=[]
for i in range(1000):
    age.append(random.randint(20,70))
    weight.append(random.randint(22,70))

# %%
plt.scatter(age,weight)

# %%
df = pd.DataFrame({'age':Age,'weight':Weight})
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-42e451c9fb3d> in <module>
# ----> 1 df = pd.DataFrame({'age':Age,'weight':Weight})
#       2 df
#
# NameError: name 'Age' is not defined

# %%
sns.regplot(x='age',y='weight',data=df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-8ac4e0fa0f80> in <module>
# ----> 1 sns.regplot(x='age',y='weight',data=df)
#
# NameError: name 'df' is not defined

# %%
Age=[]
Weight=[]

for i in range(1000):
    age=random.randint(22,70)
    Age.append(age)
    w=age*.78+random.randint(30,34)
    Weight.append(w)

# %%
plt.scatter(x=Age,y=Weight)

# %%
df = pd.DataFrame({'age':Age,'weight':Weight})

# %%
age_bar=df['age'].mean()
age_bar

# %%
sns.countplot(df.age)

# %%
weight_bar=df['weight'].mean()
weight_bar

# %%
sns.countplot(df.weight)

# %%
plt.boxplot(df.age)

# %%
plt.boxplot(df.weight)

# %%
df

# %%
df['Agedeviation']=df['age']-df['age'].mean()
df['Weightdeviation']=df['weight']-df['weight'].mean()

# %%
df

# %%
plt.scatter(x=df['Agedeviation'],y=df['Weightdeviation'])

# %%
df.describe()

# %%
from scipy.stats import norm
sns.distplot(df['Agedeviation'],fit=norm,kde=True)

# %%
from scipy.stats import norm
sns.distplot(df['age'],fit=norm,kde=True)

# %%
df['deviationScaling']=df['Agedeviation']*df['Weightdeviation']

# %%
df

# %%
df['AgedeviationNeutral']=df['Agedeviation']**2

# %%
df.head()

# %%
B1=df['deviationScaling'].sum()/df['AgedeviationNeutral'].sum()
B1

# %%
beta1=np.sum(df['deviationScaling'])/np.sum(df['AgedeviationNeutral'])
beta1

# %%
plt.scatter(df['age'],df['age']*0.78)

# %%
intercept=np.mean(df['weight']-B1*np.mean(df['age'])
intercept

# %%
plt.scatter(df['age'],df['weight'])

# %%
from sklearn.linear_model import LinearRegression

# %%
X=[]
for i in df['age']:
    X.append([i])

# %%
reg = LinearRegression().fit(X,df['weight'])
reg

# %%
reg.coef_
# Out:
# array([0.78086555])

# %%
reg.score(X,df['weight'])
# Out:
# 0.9851394460020995

# %%
reg.intercept_
# Out:
# 31.94838855727462

# %%
reg.score(X,df['age'])
# Out:
# -0.5180752295565059

# %%
print(reg(summary))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-543543c05675> in <module>
# ----> 1 print(reg(summary))
#
# NameError: name 'reg' is not defined
